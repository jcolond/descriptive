# %%
import pandas as pd

# %%
import statsmodels as sm

# %%
pwd
# Out:
# 'C:\\Users\\Jay Colond\\Box\\2022-2023\\Proposal research'

# %%
data = pd.read_stata("\\Users\\Jay Colond\\Box\\2022-2023\\Proposal research\\IPUMS\\usa_00004.dta")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\io\stata.py:1929, in StataReader._do_convert_categoricals(self, data, value_label_dict, lbllist, order_categoricals)
#    1927 try:
#    1928     # Try to catch duplicate categories
# -> 1929     cat_data.categories = categories
#    1930 except ValueError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\categorical.py:749, in Categorical.categories(self, categories)
#     747 @categories.setter
#     748 def categories(self, categories):
# --> 749     new_dtype = CategoricalDtype(categories, ordered=self.ordered)
#     750     if self.dtype.categories is not None and len(self.dtype.categories) != len(
#     751         new_dtype.categories
#     752     ):
#
# ...
